# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
import datetime as dt
#!pip install mplfinance
import matplotlib.dates as mdates 
from mplfinance import *
import pandas_datareader.data as web

style.use('ggplot')

df = pd.read_csv('tsla.csv', parse_dates=True, index_col=0)

# %%
#ax1 = plt.subplot2grid((6,1), (0,0), rowspan=5, colspan=1)
#ax2 = plt.subplot2grid((6,1), (5,0), rowspan=1, colspan=1, sharex=ax1)

# %%
df_ohlc = df['Adj Close'].resample('10D').ohlc()
df_vol = df['Volume'].resample('10D').sum()
df_ohlc['volume'] = df_vol
#df_ohlc.reset_index(inplace=True)

# %%
print(df_ohlc.head())
print(df_vol.head())
# Out:
#              open   high    low  close       volume
# Date
# 2010-06-29  4.778  4.778  3.160  3.492  354060000.0
# 2010-07-09  3.480  4.128  3.410  4.128   97447500.0
# 2010-07-19  4.382  4.382  4.044  4.144   45924000.0
# 2010-07-29  4.070  4.390  3.918  3.918   27213000.0
# 2010-08-08  3.920  3.920  3.520  3.830   25751500.0
# Date
# 2010-06-29    354060000.0
# 2010-07-09     97447500.0
# 2010-07-19     45924000.0
# 2010-07-29     27213000.0
# 2010-08-08     25751500.0
# Freq: 10D, Name: Volume, dtype: float64

# %%
#df_ohlc['Date'] = df_ohlc['Date'].map(mdates.date2num)
mplfinance.plot(df_ohlc[-37:], type='candle', volume=True, mav=(5,7,15,30))

# %%
plt.style.use('fivethirtyeight')
mplfinance.plot(df_ohlc[:], type='candle', volume=True, mav=(5,7,15,30))
