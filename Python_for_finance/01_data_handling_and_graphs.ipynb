# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
import datetime as dt
import pandas_datareader.data as web

# %%
style.use('ggplot')

start = dt.datetime(2001, 11, 19)
end = dt.datetime(2020, 12, 20)

# %%
df = web.DataReader('BURGERKING.NS', 'yahoo', start, end)
print(df.head())
print(df.tail())
# df.to_csv('tsla.csv') // converts dataframe to csv
# Out:
#                   High         Low        Open       Close     Volume  \
# Date
# 2020-12-14  135.000000  108.400002  112.500000  135.000000  186792834
# 2020-12-15  162.000000  145.000000  147.000000  162.000000   60070880
# 2020-12-16  194.399994  178.899994  184.000000  194.399994   21103499
# 2020-12-17  213.800003  175.000000  213.800003  175.000000   20515521
# 2020-12-18  161.199997  157.500000  158.000000  157.500000    5185618
#
#              Adj Close
# Date
# 2020-12-14  135.000000
# 2020-12-15  162.000000
# 2020-12-16  194.399994
# 2020-12-17  175.000000
# 2020-12-18  157.500000
#                   High         Low        Open       Close     Volume  \
# Date
# 2020-12-14  135.000000  108.400002  112.500000  135.000000  186792834
# 2020-12-15  162.000000  145.000000  147.000000  162.000000   60070880
# 2020-12-16  194.399994  178.899994  184.000000  194.399994   21103499
# 2020-12-17  213.800003  175.000000  213.800003  175.000000   20515521
# 2020-12-18  161.199997  157.500000  158.000000  157.500000    5185618
#
#              Adj Close
# Date
# 2020-12-14  135.000000
# 2020-12-15  162.000000
# 2020-12-16  194.399994
# 2020-12-17  175.000000
# 2020-12-18  157.500000

# %%
#df = pd.read_csv('tsla.csv', parse_dates=True, index_col=0 )
# print(df.head())
df['Volume'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df['High'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df['Adj Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>
